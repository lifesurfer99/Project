# %%
import pandas as pd

df = pd.read_json("./sinchon1.json")

# %%
df.to_csv("sinchon1.csv", encoding='utf-8-sig')

# %%
dataset = pd.read_csv("sinchon.csv", index_col=0)
dataset
# Out:
#                               bloggerlink                 bloggername  \
# 0          https://blog.naver.com/ssyj963                    냥냠의 일상냠냠
# 1       https://blog.naver.com/reading321               감성 (感性) [감ː성]
# 2    https://blog.naver.com/audtjsl841510                Carpe diem ♥
# 3           https://blog.naver.com/ferang                    젬므의 졔라운지
# 4          https://blog.naver.com/everlsk       사진에 세상을 담다 by everlsk
# 5            https://blog.naver.com/hwi95  Coffee, Cafe & Programming
# 6         https://blog.naver.com/maya_lee                 좋은 엄마 되기...
# 7        https://blog.naver.com/donghwa11                낭만이 우리의 주체사상
# 8           https://blog.naver.com/yl2631                     쓰담쓰담 :)
# 9           https://blog.naver.com/nddoo_                    뚜뚜뚜루뚜뚜뚜뚜
# 10        https://blog.naver.com/jackie30               젝키30의 소소한 사진관
# 11     https://blog.naver.com/candypowder              TODAY TOMORROW
# ...

# %%
title = df['title']
print(title)
# Out:
# 0                                  중독적인 매운맛 <b>신촌 맛</b>집
# 1                         <b>신촌</b> 밥집 계속 아른거리는 <b>맛</b>
# 2                      <b>신촌</b> 마라탕 깊고 진한 맛에 반한 천궁전마라탕!
# 3      &lt;서울 <b>신촌</b>&gt; [<b>신촌</b> / 이빠네마그릴] 다양한 ...
# 4                                 <b>신촌 맛</b>집 새로움을 맛보다!
# 5                      [<b>신촌</b>] <b>맛</b>좋은 돈까스, 하루돈까스
# 6                              <b>신촌 맛</b>집 맛 좋은 건강한 밥상!
# 7             진짜 브라질의 <b>맛</b>! <b>신촌</b>스테이크 맛집 이빠네마 그릴
# 8                             <b>신촌</b> 촉촉베이커리 소금앙버터 개꿀맛
# 9                            <b>신촌 맛</b>집 팔덕식당 제대로된 빨간맛!
# 10                                   <b>신촌 맛</b>집 얼얼한 맛!
# 11                              <b>신촌 맛</b>집 오랜된 원조맛 그대로
# 12                              <b>신촌</b>데이트 핫한 보고 맛보고 !
# 13                    <b>신촌</b> 칵테일바 헤이븐 분위기에 취하고 맛에 취하고
# 14                              <b>신촌 맛</b>집 스트레스 날라가는 맛
# 15     <b>신촌</b> 파스타, <b>신촌</b> 스테이크; 파르미 이탈리아노/ <b>맛...
# ...

# %%
bloggernames = df['bloggername']
print(bloggernames)
# Out:
# 0                        냥냠의 일상냠냠
# 1                   감성 (感性) [감ː성]
# 2                    Carpe diem ♥
# 3                        젬므의 졔라운지
# 4           사진에 세상을 담다 by everlsk
# 5      Coffee, Cafe & Programming
# 6                     좋은 엄마 되기...
# 7                    낭만이 우리의 주체사상
# 8                         쓰담쓰담 :)
# 9                        뚜뚜뚜루뚜뚜뚜뚜
# 10                  젝키30의 소소한 사진관
# 11                 TODAY TOMORROW
# 12                         커피~타임~
# 13                꿈꾸는 간호사의 소소한 리뷰
# 14                     보물섬의 일상이야기
# 15                            하날기
# 16                      빠람 끼 딘짜르야
# 17                    Dio Factory
# 18         돈내고사먹읍시다(舊Serendipity)
# 19                먹자, 마시자, 놀러 다니자
# 20                       윤마켓엔 다있오
# 21         Kairos, In His Time...
# 22                    사진 좋아하는 열정남
# 23                       먹고 사는 재미
# 24                      익명의 에디터 K
# 25                 peerysoos님의블로그
# 26                      파고다 공식블로그
# ...
